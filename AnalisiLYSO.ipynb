// %% [markdown]
// # LYSO detector characterization
//
// ## Table of contents
// - Logbook
// - Data analysis
//
//
// # **Logbook**
// Below it has been reported the log concerned the data acquired during the lab experience.
//
// -----------------------------------
// ![diagram](./diagram.svg)
//
// - FILE NAME: LYSO3.dst ID 300
// - FILE NAME: LYSO4.dst ID 400
//
// Measurement of 200 keV or 300 keV and beta decay in the LYSO
//
// ## Oscilloscope channels
//
// - Channel 1 LYSO no amplification
// - Channel 2 LYSO amplified
// - Channel 3 NaI 1
// - Channel 4 NaI 2
//
//
// ## Oscilloscope settings
//
//
// | Channel  |  Y scale  | Trigger   |  Threshold |
// |----------|-----------|-----------|------------|
// |     1    |   2 mV    | No        |            |
// |     2    |   10 mV   | NegEdge   |   -3 mV    |
// |     3    |   10 mV   | NegEdge   |   -3 mV    |
// |     4    |   10 mV   | NegEdge   |   -3 mV    |
//
// Trigger pattern = AND
//
// --------------------------------------------------------------
//
//
// - FILE NAME Co2_1.dst ID 400
//
// Calibration of the NaI scintillators with Co 60 source
//
// | Channel  |  Y scale  | Trigger   |  Threshold |        |
// |----------|-----------|-----------|------------|--------|
// |     1    |   2 mV    | No        |            |        |
// |     2    |   2 mV    | NegEdge   |   -2 mV    | (Veto) |
// |     3    |   50 mV   | NegEdge   |    -5 mV   |        |
// |     4    |   50 mV   | NegEdge   |    -5 mV   |        |
//
// Trigger Pattern (~no.2 ) & (no. 3) & (no. 4)
//
//
// -------------------------------------------------------
//
// - FILE NAME: Co2_2.dst ID 500
//
// Calibratione of the LYSO crystal with C0 60 source
//
// | Channel  |  Y scale  | Trigger   |  Threshold |        |
// |----------|-----------|-----------|------------|--------|
// |     1    |   2 mV    | No        |            |        |
// |     2    |   10 mV   | NegEdge   |    -15 mV  |        |
// |     3    |   10 mV   | No        |    -5 mV   | (Veto) |
// |     4    |   50 mV   | NegEdge   |    -33 mV  |        |
//
// Trigger	Pattern	(no.2 ) & (~no. 3) & (no. 4)
//
//
// -----------------------------------------------
//
// - FILE NAME: Na2_1.dst
//
// Calibration with Na22 source
// LYSO should see 1200 keV
// The source is between the two NaIs
//
//
// | Channel  |  Y scale  | Trigger   |  Threshold |
// |----------|-----------|-----------|------------|
// |     1    |   2 mV    | No        |            |
// |     2    |   10 mV   | NegEdge   |    -10 mV  |
// |     3    |   20 mV   | NegEdge   |    -7 mV   |
// |     4    |   20 mV   | NegEdge   |    -7 mV   |
//
// Trigger Pattern : (no.2 ) & (no. 3) & (no. 4)
//
//
// ---------------------------------------------------------
//
// - FILE NAME : Na2_2.dst
//
// PMTs calibration
// NaI1 (ch.3) should see the 1200 keV peak while NaI2 and LYSO should se the two photons at 511 keV
//
// | Channel  |  Y scale  | Trigger   |  Threshold |
// |----------|-----------|-----------|------------|
// |     1    |   2 mV    | No        |            |
// |     2    |   10 mV   | NegEdge   |    -4 mV   |
// |     3    |   50 mV   | NegEdge   |    -10 mV  |
// |     4    |   20 mV   | NegEdge   |    -7 mV   |
//
// Trigger Pattern : (no.2 ) & (no. 3) & (no. 4)
//
// --------------------------------------------------------
//
//  - FILE NAME : LYSO5
//
// Background LYSO without sources
//
// | Channel  |  Y scale  | Trigger   |  Threshold |       |
// |----------|-----------|-----------|------------|-------|
// |     1    |   2 mV    | No        |            |       |
// |     2    |   10 mV   | NegEdge   |    -1 mV   |       |
// |     3    |   10 mV   | NegEdge   |    -5 mV   | (Veto)|
// |     4    |   10 mV   | NegEdge   |    -5 mV   | (Veto)|
//
// Trigger Pattern : (no.2 ) & (~no. 3) & (~no. 4)
//
// ------------------------------------------------
//
// -- FILE NAME : CS2
//
// Measurement of the gamma spectrum of Cs 137. Measurement to do after the calibration.
//
// | Channel  |  Y scale  | Trigger   |  Threshold |       |
// |----------|-----------|-----------|------------|-------|
// |     1    |   2 mV    | No        |            |       |
// |     2    |   10 mV   | NegEdge   |    -1 mV   |       |
// |     3    |   10 mV   | NegEdge   |    -5 mV   | (Veto)|
// |     4    |   10 mV   | NegEdge   |    -5 mV   | (Veto)|
//
// Trigger Pattern : (no.2 ) & (~no. 3) & (~no. 4)
//
// ---------------------------------------------------------------
//
// - FILE NAME : LYSO6
//
// Background measurement
//
// | Channel  |  Y scale  | Trigger   |  Threshold |
// |----------|-----------|-----------|------------|
// |     1    |   2 mV    | No        |            |
// |     2    |   10 mV   | NegEdge   |    -1 mV   |
// |     3    |   10 mV   | NegEdge   |    -5 mV   |
// |     4    |   10 mV   | NegEdge   |    -5 mV   |
//
// Trigger Pattern : (no.2 ) & (~no. 3) & (~no. 4)
//
// ---------------------------------------------------
//
// # **Data analysis**
//
// First, I am going to display the histogram acquired from the LYSO crystal without any sources.
// - The file name used is LYSO3.dst and LYSO4.dst.
// - The script used is LYSO_NaI1_NaI2.c
//
// ## LYSO Background measurement
// The first mesure consists of the measurement of the background due to the intrinsic radioactivity of the LYSO crystal. In order to perform this measurement we have used the following configuration:
// - LYSO crystal in the middle of the experimental setup
// - 2 NaI crystal scintillators
// - Triggering pattern used is given by: NaI1 & NaI2 & LYSO(amplificated) (NOTE: & is a logical AND port)
//
// ![LYSO A3 A4](/docs/assets/images/LYSO_A3_A4.png)
// ![LYSO A3 A4](/docs/assets/images/LYSO_PK3_PK4.png)
//
//
// After filtering data using some masks it is possible to see the **Pulse height spectrum** (or better, the area spectrum) of the LYSO crystal
//
// ![LYSO A3 spectrum](/docs/assets/images/NaI1_LYSO_Spectrum.png)
// ![LYSO A4 spectrum](/docs/assets/images/NaI2_LYSO_Spectrum.png)
//
// ## Calibration of the NaI scintillators and LYSO
//
// ### NaI calibration with Co and pedestal LYSO
//
// Exploiting the configuration in which the LYSO, which is removed from the table on which are positioned the two NaI, is vetoed, it is possible to calibrate the two NaI.
// Below the spectra measured with the Co source
//
// ![1 2 Co spectrum](/docs/assets/images/Co_spectrum_NaI1_NaI2.png)
//
// ![1 Co spectrum](/docs/assets/images/NaI1_Co_calib.png)
// ![2 Co spectrum](/docs/assets/images/NaI2_Co_calib.png)
//
// Since the LYSO is vetoed it is possible to exploit this configuration to measure the pedestal. The area, in fact, is not exactly calibrated since the signal is affected by a small baseline.
//
//
// ![Pedestal](/docs/assets/images/LYSO_pedestal.png)
//
// This histogram is obtained by using the area measured by the channel 2 which is exactly the LYSO crystal, shilded by a Pb coating.
//
//
// ### LYSO Calibration with Co
//
// In order to calibrate LYSO we need to put NaI1 in anticoincidence with the LYSO and the NaI2. The file used for this section is **Co2_2.dst**. See the loogbook. Below, the histogram shows that it is quite difficult to distinguish the two Co peaks using only the LYSO because its resolution is lower respect to the resolution of the NaI.
//
// ![co lyso](/docs/assets/images/Co_spectrum_NaI2_LYSO.png)
//
// Using the coincidence detection with one of the two NaI we can select some particularly useful events.
// Here, the zoom on the area of interest. Using some mask applied on the data we can select the useful events for the calibration.
//
// ![co lyso](/docs/assets/images/Co_spectrum_zoom_peaks.png)
//
// After a careful selection of the data we are able to distinguish the two Co peaks in the LYSO
//
// ![co lyso](/docs/assets/images/Co_LYSO_peak_1173.png)
//
// ![co lyso](/docs/assets/images/Co_LYSO_peak_1332.png)
//
// From the fit we can measure the value of the center of the gaussian shapes and the resolutions of the peaks

// %%
//%jsroot on

// %%
// Record for calibration
ofstream calfile;
calfile.open("docs/group2/Calib_data.txt",ios::app);
calfile<<"# ene \t cal \t ecal \t syscal \t sigma \t esigma "<<endl;

// %% [markdown]
// # LYSO Background Measurement

// %%
TString PREFIX = "DST/group2/";

TString Fname0=PREFIX + "LYSO3.dst";
TString Fname1=PREFIX + "LYSO4.dst";

// IMPORTAZIONE DEI DATI
TTree* tree = new TTree("tree","data from ascii file"); 
tree->ReadFile(Fname0.Data(),"evnum/I:A1/F:A2/F:A3/F:A4/F:T12/F:T32/F:T42/F:T34/F:PK1/F:PK2/F:PK3/F:PK4/F");
tree->ReadFile(Fname1.Data(),"evnum/I:A1/F:A2/F:A3/F:A4/F:T12/F:T32/F:T42/F:T34/F:PK1/F:PK2/F:PK3/F:PK4/F");

// %%
// Istogrammi 2D per i tempi per puilire i dati

// MASCHERA 
TString Mask0 = "T34!=0 && T32!=0 && T42!=0 && T12!=0 &&";
TString Mask1 = "abs(-T32+5e-9)<0.3e-7 && abs(-T42+10e-9)<0.3e-7 &&";
TString Mask2 = "abs(-T12 +0.04e-6)<0.4e-7 &&";
TString Mask3 = "(-A4/PK4-0.22e-6)<0.07e-6 && (-A3/PK3-0.21e-6)<0.1e-6 &&";
TString Mask4 = "-A4<16e-9 & -A3<16e-9";
TString Mask = Mask0 + Mask1 + Mask2 + Mask3 + Mask4;

// ISTOGRAMMI TEMPI
// Pulisco i dati guardando i tempi
TCanvas* c1 = new TCanvas();
tree->Draw("-T32:-T42", Mask, "colz");
c1->Draw();
//c1->SaveAs("docs/group2/images/LYSO_T32_T42.png");

// %%
TCanvas* c2 = new TCanvas();
tree->Draw("-T32:-T12", Mask , "colz");
//c2->SaveAs("docs/group2/images/LYSO_T32_T12.png");
c2->Draw();

// %%
// ISTOGRAMMI AREE/PICCHI
// Pulisco i dati eliminando gli eventi di pile-up
TCanvas* c3 = new TCanvas();
tree->Draw("-A3/PK3:-A4/PK4", Mask , "colz");
c3->Draw();

// %%
// istogramma 2D delle aree NaI1 NaI2
TCanvas* a1 = new TCanvas();
tree->Draw("-A3:-A4", Mask ,"colz");                    // AREE
//a1->SaveAs("docs/group2/images/LYSO_A3_A4.png");
a1->Draw();

// %%
TCanvas* a2 = new TCanvas();
tree->Draw("PK3:PK4", Mask , "colz");                   // PICCHI
// Istogrammi con dati filtrati 
//a2->SaveAs("docs/group2/images/LYSO_PK3_PK4.png");
a2->Draw();

// %%
// ISTOGRAMMA UNIDIMENSIONALE DEI NaI

// ***********************************
//  NaI 1 
// ***********************************

TCanvas* a3 = new TCanvas();
//a3->SetGrid();
TH1D* h1= new TH1D("h1", "LYSO spectrum from NaI1;NaI1 [Vs];Events",100,1e-11, 15e-9);
//h1->SetStats(0);
tree->Draw("-A3>>h1",Mask,"");
gPad->SetLogy();
//a3->SaveAs("docs/group2/images/NaI1_LYSO_Spectrum.png");
a3->Draw();

// ***********************************
//  NaI 2 
// ***********************************

TCanvas* a4 = new TCanvas();
//a4->SetGrid();
TH1D* h2= new TH1D("h2","LYSO spectrum from NaI2;NaI2 [Vs];Events",100,1e-10, 12e-9);
h2->SetStats(0);
tree->Draw("-A4>>h2",Mask,"");
gPad->SetLogy();
//a4->SaveAs("docs/group2/images/NaI2_LYSO_Spectrum.png");
a4->Draw();

// %% [markdown]
// # Calibration of the LYSO with Co60 source

// %%
TString Fname = PREFIX + "Co2_1.dst";

TTree* tree = new TTree("tree","data from ascii file"); 
tree->ReadFile(Fname.Data(),"evnum/I:A1/F:A2/F:A3/F:A4/F:T12/F:T32/F:T42/F:T34/F:PK1/F:PK2/F:PK3/F:PK4/F");

TString Mask_Co_0 = "-A3/PK3<0.4e-6 && -A4/PK4<0.4e-6 && T34!=0 && -A3<0.08e-6 && -A4<0.08e-6";
TString Mask_Co_1 = "&& T34!=0 && abs(-T34 -4e-9)<11e-9";
TString Mask_Co = Mask_Co_0 + Mask_Co_1;

TCanvas* a5 = new TCanvas();
TH2D* h2d= new TH2D("h2d",";NaI1[Vs]; NaI2 [Vs]",70,0,60e-9,70,0,60e-9);
h2d->SetStats(0);
tree->Draw("-A4:-A3>>h2d",Mask_Co,"colz");
a5->Draw();
//a5 -> SaveAs("docs/group2/images/Co60_spectrum_NaI1_NaI2.png");

// %%
// Histogram Co_60
TCanvas* a6 = new TCanvas();
//a6->SetGrid();
TH1D* h3= new TH1D("h3",";NaI1 [Vs];Events",150,38e-9, 54e-9);
h3->SetStats(0);
tree->Draw("-A3>>h3",Mask_Co,"");
gPad->SetLogy();
//a6->SaveAs("docs/group2/images/Co60_spectrum_NaI1.png");

// Fits
TF1* f1 = new TF1("f1","gaus+gaus(3) + [6]* TMath::Exp(-x/[7])",38e-9, 54e-9);
f1->SetParameter(0,250);
f1->SetParameter(1,42e-9);
f1->SetParameter(2,0.5e-9);
f1->SetParameter(3,200);
f1->SetParameter(4,47e-9);
f1->SetParameter(5,0.5e-9);
f1->SetParameter(6,80);
f1->SetParameter(7, 20e-9);
f1->SetParNames("const 1333 keV", "mean 1333 keV", "sigma 1333 keV", "const 1173 keV", "mean 1173 keV", "sigma 1173 keV");
h3->Fit("f1","L","",38e-9, 54e-9);

a6->Draw();

double Co_NaI1_1      = f1->GetParameter(1);
double dCo_NaI1_1     = f1->GetParError(1);
double Res_Co_NaI1_1  = f1->GetParameter(2);
double dRes_Co_NaI1_1 = f1->GetParError(2);
double Co_NaI1_2      = f1->GetParameter(4);
double dCo_NaI1_2     = f1->GetParError(4);
double Res_Co_NaI1_2  = f1->GetParameter(5);
double dRes_Co_NaI1_2 = f1->GetParError(5);
// Out:
//  FCN=69.3648 FROM MIGRAD    STATUS=CONVERGED    1128 CALLS        1129 TOTAL
//                      EDM=9.42348e-08    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  const 1333 keV   3.96400e+01   2.00751e+00   9.04577e-03  -1.15302e-04
//    2  mean 1333 keV   4.15739e-08   5.18186e-11   2.80074e-13  -2.33568e+06
//    3  sigma 1333 keV   1.02655e-09   5.28756e-11   1.98932e-13  -4.65910e+06
//    4  const 1173 keV   3.77936e+01   1.67866e+00   7.63326e-03   8.05311e-05
//    5  mean 1173 keV   4.70407e-08   4.60956e-11   2.63009e-13   2.00656e+06
//    6  sigma 1173 keV   1.14339e-09   4.53330e-11   1.82237e-13   3.59569e+06
//    7  p6           6.99477e+03   3.10920e+03   1.62941e+00  -5.54074e-07
//    8  p7           6.49243e-09   4.35108e-10   2.30252e-13  -3.77248e+06
//                                ERR DEF= 0.5

// %%
TCanvas* a7 = new TCanvas();
//a7->SetGrid();
TH1D* h4= new TH1D("h4",";NaI2 [Vs];Events",150,30e-9, 45e-9);
h4->SetStats(0);
tree->Draw("-A4>>h4",Mask_Co,"");
gPad->SetLogy();

TF1* f2 = new TF1("f2","gaus+gaus(3) + [6]* TMath::Exp(-x/[7])",30e-9, 45e-9);
f2->SetParameter(0,60);
f2->SetParameter(1,34e-9);
f2->SetParameter(2,0.5e-9);
f2->SetParameter(3,60);
f2->SetParameter(4,39e-9);
f2->SetParameter(5,0.5e-9);
f2->SetParameter(6,30);
f2->SetParameter(7, 30e-9);
f2->SetParNames("const 1333 keV", "mean 1333 keV", "sigma 1333 keV", "const 1173 keV", "mean 1173 keV", "sigma 1173 keV");
h4->Fit("f2","L","",30e-9, 45e-9);
a7->Draw();

//a7 -> SaveAs("docs/group2/images/Co60_NaI2_calib.png");

double Co_NaI2_1      = f2->GetParameter(1);
double dCo_NaI2_1     = f2->GetParError(1);
double Res_Co_NaI2_1  = f2->GetParameter(2);
double dRes_Co_NaI2_1 = f2->GetParError(2);
double Co_NaI2_2      = f2->GetParameter(4);
double dCo_NaI2_2     = f2->GetParError(4);
double Res_Co_NaI2_2  = f2->GetParameter(5);
double dRes_Co_NaI2_2 = f2->GetParError(5);
// Out:
//  FCN=94.4434 FROM MIGRAD    STATUS=CONVERGED    1102 CALLS        1103 TOTAL
//                      EDM=1.48675e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  const 1333 keV   4.77327e+01   2.22310e+00   1.16833e-02   1.31997e-04
//    2  mean 1333 keV   3.45691e-08   4.25423e-11   2.66261e-13   1.33847e+06
//    3  sigma 1333 keV   9.13684e-10   4.21908e-11   1.93041e-13  -5.99325e+04
//    4  const 1173 keV   5.07359e+01   2.10207e+00   1.12833e-02  -1.01130e-04
//    5  mean 1173 keV   3.91235e-08   3.26960e-11   2.18617e-13  -4.40324e+06
//    6  sigma 1173 keV   8.70894e-10   3.02949e-11   1.47643e-13  -3.22921e+06
//    7  p6           5.22369e+03   1.62635e+03   1.13907e+00  -3.57321e-07
//    8  p7           5.72681e-09   3.07101e-10   2.11111e-13  -2.06749e+06
//                                ERR DEF= 0.5

// %% [markdown]
// #### Pedistals: baseline that affects the area (like a shift in alto)

// %%
// *********************
// Fit pedestal

double x0 = -0.37e-9;; //lower limit 
double x1 = -0.05e-9; //upper limit 
int Nbin = 150;

TCanvas* aped = new TCanvas();
aped->SetGrid();

TH1D *hped = (TH1D*) gROOT->FindObject("hped");
if (hped) delete hped;
hped= new TH1D("hped",";LYSO [Vs];Events",Nbin,x0,x1);

//hped->SetStats(0);

tree->Draw("-A2>>hped",Mask_Co,"");
gPad->SetLogy();

TF1* f20 = new TF1("f20","gaus+ [3]*TMath::Exp(-x/[4])",x0,x1);
f20->SetParameter(0,100);
f20->SetParameter(1,-0.22e-9);
f20->SetParameter(2,0.05e-9);
f20->SetParameter(3,10);
f20->SetParameter(4,0.1e-9);
f20->SetParNames("const", "mean", "sigma", "a3", "a4");
hped->Fit("f20","L","", x0, x1);
gStyle->SetOptStat(0);
gStyle->SetOptFit(1);
//gStyle->SetStatFontSize(0.02);
aped->Draw();
//a70 -> SaveAs("LYSO_pedestal_hist_fit.png");

double pedestal_centre  = f20->GetParameter(1);
double dpedestal_centre = f20->GetParError(1);
double pedestal_res  = f20->GetParameter(2);
double dpedestal_res = f20->GetParError(2);
// Out:
//  FCN=93.9581 FROM MIGRAD    STATUS=CONVERGED     385 CALLS         386 TOTAL
//                      EDM=3.93291e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.5 per cent
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  const        2.00706e+02   2.30758e+00  -1.87369e-03  -1.55620e-04
//    2  mean        -2.16311e-10   4.88914e-13  -7.08269e-16   3.24320e+08
//    3  sigma        5.07582e-11   3.86486e-13  -4.87581e-16  -1.69625e+09
//    4  a3          -4.34495e-02   1.02275e-02  -4.34428e-07  -3.24281e-02
//    5  a4           1.01329e-10   1.19601e-13  -1.28440e-16   7.01618e+09
//                                ERR DEF= 0.5

// %%
calfile << "0 \t " << pedestal_centre << "\t " << dpedestal_centre << "\t 0 \t " << pedestal_res << "\t " << dpedestal_res << endl;

// %%
TString Mask_Pedestal = "&& abs(-A1)<0.1e-9 && abs(-A2+0.2e-9)<0.2e-9";

TCanvas* a8 = new TCanvas();
TH2D* h2d= new TH2D("h2d",";-T34 [Vs];LYSO [Vs];",70,-10e-9,17e-9,70,-0.4e-9,0);
tree->Draw("-A2:-T34>>h2d", Mask_Co+Mask_Pedestal, "colz");
//a8 -> SaveAs("docs/group2/images/LYSO_pedestal.png");
a8->Draw();
// Out:
// Warning in <TROOT::Append>: Replacing existing TH1: h2d (Potential memory leak).

// %%
cout << "NaI 1\n";
cout << "1173\t" << Co_NaI1_1 << "\t" << dCo_NaI1_1 << "\t" << Res_Co_NaI1_1 << "\t" << dRes_Co_NaI1_1 << "\t\n";
cout << "1332\t" << Co_NaI1_2 << "\t" << dCo_NaI1_2 << "\t" << Res_Co_NaI1_2 << "\t" << dRes_Co_NaI1_2 << "\t\n";


cout << "NaI 2\n";
cout << "1173\t" << Co_NaI2_1 << "\t" << dCo_NaI2_1 << "\t" << Res_Co_NaI2_1 << "\t" << dRes_Co_NaI2_1 << "\t\n";
cout << "1332\t" << Co_NaI2_2 << "\t" << dCo_NaI2_2 << "\t" << Res_Co_NaI2_2 << "\t" << dRes_Co_NaI2_2 << "\t\n";

cout << "LYSO Pedestal\n";
cout << "0\t" << pedestal_centre << "\t" << dpedestal_centre << "\t" << pedestal_res << "\t" << dpedestal_res << "\t\n";
// Out:
// NaI 1
// 1173	4.15739e-08	5.18186e-11	1.02655e-09	5.28756e-11
// 1332	4.70407e-08	4.60956e-11	1.14339e-09	4.5333e-11
// NaI 2
// 1173	3.45691e-08	4.25423e-11	9.13684e-10	4.21908e-11
// 1332	3.91235e-08	3.2696e-11	8.70894e-10	3.02949e-11
// LYSO Pedestal
// 0	-2.16311e-10	4.88914e-13	5.07582e-11	3.86486e-13

// %%
TString Fname5 = "DST/group2/Co2_2.dst";

TTree* tree2 = new TTree("tree2","data from ascii file"); 
tree2->ReadFile(Fname5.Data(),"evnum/I:A1/F:A2/F:A3/F:A4/F:T12/F:T32/F:T42/F:T34/F:PK1/F:PK2/F:PK3/F:PK4/F");


TString Mask_Co2_0 = "T12!=0 && T42!=0 && abs(-T12+0.04e-6)<0.2e-7 && abs(-T42+0.01e-6)<0.7e-7";
TString Mask_Co2_1 ="&& abs(-A2/PK2 -0.09e-6)<0.03e-6 && abs(-A4/PK4-0.28e-6)<0.1e-6";
TString Mask_Co2_2 = "&& -A4>0.03e-6 && -A4<0.05e-6 && -A2>2e-9 && -A2<9e-9";
TString Mask_Co2 = Mask_Co2_0 + Mask_Co2_1 + Mask_Co2_2;

// Pulisco i dati guardando i tempi

TCanvas* a9 = new TCanvas();
// Elimino i Pile up
tree2->Draw("-A4/PK4:-A2/PK2",Mask_Co2, "colz");

TCanvas* a50 = new TCanvas();
TH2D* h2d0= new TH2D("h2d0",";LYSO [Vs]; NaI2 [Vs]",70,1e-9,9e-9,70,8e-9,50e-9);
h2d0->SetStats(0);
tree2->Draw("-A4:-A2>>h2d0",Mask_Co2_0 + Mask_Co2_1,"colz");
//a50 -> SaveAs("docs/group2/images/Co60_spectrum_NaI2_LYSO.png");
a50->Draw();
// Out:
// Error in <TBranch::WriteBasketImpl>: basket's WriteBuffer failed.
// Error in <TBranch::TBranch::Fill>: Failed to write out basket.
//
// Error in <TTree::Fill>: Failed filling branch:tree2.evnum, nbytes=-1, entry=7981
//  This error is symptomatic of a Tree created as a memory-resident Tree
//  Instead of doing:
//     TTree *T = new TTree(...)
//     TFile *f = new TFile(...)
//  you should do:
//     TFile *f = new TFile(...)
//     TTree *T = new TTree(...)
//
//
// Error in <TBranch::WriteBasketImpl>: basket's WriteBuffer failed.
// Error in <TBranch::TBranch::Fill>: Failed to write out basket.
//
// Error in <TTree::Fill>: Failed filling branch:tree2.A1, nbytes=-1, entry=7982
//  This error is symptomatic of a Tree created as a memory-resident Tree
//  Instead of doing:
//     TTree *T = new TTree(...)
//     TFile *f = new TFile(...)
//  you should do:
//     TFile *f = new TFile(...)
//     TTree *T = new TTree(...)
//
//
// ...

// %%
TCanvas* a10 = new TCanvas();
tree2->Draw("-A4:-A2",Mask_Co2+"&& -A3<1e-9", "colz");
//a10 -> SaveAs("docs/group2/images/Co60_spectrum_zoom_peaks.png");
a10->Draw();

TString Mask_Co_peak1 = "&& -A4>34.1e-9 && -A4<35.5e-9";

TCanvas* a11 = new TCanvas();
a11->SetGrid();
TH1D* h5= new TH1D("h5","Peak @ 1332 keV;NaI2 [Vs];Events",20,0e-9,40e-9);
h5->SetStats(0);
tree2->Draw("-A4>>h5",Mask_Co2+Mask_Co_peak1,"");
gPad->SetLogy();
//a11->SaveAs("docs/group2/images/Co60_NaI2_peak_1332.png");
//a11->Draw();

// %%
TCanvas *a12 = (TCanvas*) gROOT->FindObject("a12");
if (a12) delete a12;
a12 = new TCanvas();
a12->SetGrid();

TH1D *h6 = (TH1D*) gROOT->FindObject("h6");
if (h6) delete h6;
h6 = new TH1D("h6","Peak @ 1332 keV;LYSO [Vs];Events",70,4e-9,9e-9);
//tree2->Draw("-A2>>h6",Mask_Co2+Mask_Co_peak1,"");
tree2->Draw("-A2>>h6",Mask_Co2,"");
gPad->SetLogy();
TF1* f12 = new TF1("f12","gaus+ [3] /(1 + (x/[4])**[5])",4e-9,9e-9);
f12->SetParameter(0,60);
f12->SetParameter(1,6.1e-9);
f12->SetParameter(2,0.3e-9);
f12->SetParameter(3,10);
f12->SetParameter(4,6e-9);
f12->SetParameter(5,3);
f12->SetParNames("const 1332 keV", "mean 1332 keV", "sigma 1332 keV", "a3", "a4", "a5");

h6->Fit("f12","L","", 4e-9, 9e-9);
//a12->SaveAs("docs/group2/images/Co60_LYSO_peak_1332.png");
/*gStyle->SetOptStat(0);
h6->SetStats("True");
gStyle->SetStatFontSize(0.02);*/

a12->Draw();
// Out:
//  FCN=55.9803 FROM MIGRAD    STATUS=CONVERGED     536 CALLS         537 TOTAL
//                      EDM=1.14032e-06    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  const 1332 keV   4.75292e+01   3.68417e+00   7.47710e-03  -4.34469e-05
//    2  mean 1332 keV   6.16860e-09   8.44431e-11   1.55832e-13   2.45558e+07
//    3  sigma 1332 keV   9.33352e-10   4.31329e-11   9.79883e-14   1.72982e+07
//    4  a3           3.98845e+01   3.79646e+00   7.56212e-03  -5.18096e-04
//    5  a4           6.14354e-09   9.13803e-11   2.82637e-13  -8.02441e+06
//    6  a5           3.83778e+01   8.93311e+00   4.31253e-02  -3.77050e-05
//                                ERR DEF= 0.5

// %%
TString Mask_Co_peak2 = "&& -A4>38.5e-9 && -A4<40.5e-9";

gStyle->SetOptStat(0);
gStyle->SetStatFontSize(0.02);

TCanvas* a14 = new TCanvas();
a14->SetGrid();
TH1D* h8= new TH1D("h8","",60,37e-9,43e-9);
//h8->SetStats(0);
tree2->Draw("-A4>>h8",Mask_Co2+Mask_Co_peak2,"");
gPad->SetLogy();

TCanvas* a13 = new TCanvas();
a13->SetGrid();
TH1D* h7= new TH1D("h7","Peak @ 1173 keV;LYSO [Vs]; Events",70,3e-9,7.5e-9);
//h7->SetStats(0);
tree2->Draw("-A2>>h7",Mask_Co2+Mask_Co_peak2,"");
gPad->SetLogy();

TF1* f13 = new TF1("f13","gaus+ [3] /(1 + (x/[4])**[5])",3e-9,7.5e-9);
f13->SetParameter(0,60);
f13->SetParameter(1,5.9e-9);
f13->SetParameter(2,0.5e-9);
f13->SetParameter(3,11);
f13->SetParameter(4,5e-9);
f13->SetParameter(5,2);
f13->SetParNames("const 1173 keV", "mean 1173 keV", "sigma 1173 keV", "a3", "a4", "a5");
h7->Fit("f13","L","", 3e-9, 7.5e-9);
gStyle->SetOptStat(0);
gStyle->SetOptFit(1);
//gStyle->SetStatFontSize(0.02);
a13->Draw();
//a13->SaveAs("docs/group2/images/Co60_LYSO_peak_1173.png");
// Out:
//  FCN=36.6846 FROM MIGRAD    STATUS=CONVERGED     317 CALLS         318 TOTAL
//                      EDM=2.51544e-09    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   3.2 per cent
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  const 1173 keV   2.10121e+01   2.08082e+00   2.49016e-04   2.65046e-05
//    2  mean 1173 keV   5.50157e-09   3.61124e-11   1.54488e-14   7.63149e+05
//    3  sigma 1173 keV   3.45548e-10   4.18848e-11  -3.50599e-14   1.18493e+05
//    4  a3           1.10363e+01   6.90564e-01   1.99062e-05   1.69542e-05
//    5  a4           6.83049e-09   1.98801e-10  -1.48125e-14   1.83167e+05
//    6  a5           9.73295e+00   4.49670e+00   3.21908e-03  -4.62550e-06
//                                ERR DEF= 0.5

// %%
cout << "Cobalto LYSO\n";
cout << "1173\t" << (f13->GetParameter(1)) << "\t" <<(f13->GetParError(1)) << "\t" <<(f13->GetParameter(2))<< "\t" << (f13->GetParError(2)) << "\n";
cout << "1332\t" << (f12->GetParameter(1)) << "\t" <<(f12->GetParError(1)) << "\t" <<(f12->GetParameter(2))<< "\t" << (f12->GetParError(2)) << "\n";

calfile << "1173\t" << (f13->GetParameter(1)) << "\t" <<(f13->GetParError(1)) << "\t 0 \t" <<(f13->GetParameter(2))<< "\t" << (f13->GetParError(2)) << endl;
calfile << "1332\t" << (f12->GetParameter(1)) << "\t" <<(f12->GetParError(1)) << "\t 0 \t" <<(f12->GetParameter(2))<< "\t" << (f12->GetParError(2)) << endl;
// Out:
// Cobalto LYSO
// 1173	5.50157e-09	3.61124e-11	3.45548e-10	4.18848e-11
// 1332	6.16879e-09	5.64287e-11	3.81268e-10	5.86436e-11

// %% [markdown]
// # Calibration of the LYSO with Na22 source

// %% [markdown]
// ### 1st configuration

// %%
TString Fname6 = "DST/group2/Na2_1.dst";

TTree* tree4 = new TTree("tree4","data from ascii file");
tree4->ReadFile(Fname6.Data(),"evnum/I:A1/F:A2/F:A3/F:A4/F:T12/F:T32/F:T42/F:T34/F:PK1/F:PK2/F:PK3/F:PK4/F");

TString Mask_Na22_0= "T12!=0 && abs(T12-0.04e-6)<20e-9";
TString Mask_Na22_1= "&& abs(-A4 -19e-9)<5e-9 && abs(-A3-24e-9)<5e-9";
TString Mask_Na22_2= "&& T32!=0 && T42!=0 && abs(T32-8e-9)<0.012e-6 && abs(T42-8e-9)<0.012e-6 && T12>35e-9";
TString Mask_Na22_3= "&& abs(-A3-23e-9)<2.5e-9 && abs(-A4-19e-9)<2.2e-9";
TString Mask_Na22 = Mask_Na22_0 + Mask_Na22_1 + Mask_Na22_2 + Mask_Na22_3;

// %%
// ISTOGRAMMI TEMPI
TCanvas* c41 = new TCanvas();
//c41->SetGrid();
c41->SetTitle("Na_T32_T12");
tree4->Draw("T32:T12", Mask_Na22, "colz");
c41->Draw();

// %%
// ISTOGRAMMI AREE/PICCHI
TCanvas* c43 = new TCanvas();
c43->SetTitle("Areas/peaks");
tree4->Draw("-A3/PK3:-A4/PK4", Mask_Na22, "colz");
c43->Draw();

// %%
// istogramma 2D delle aree NaI1 NaI2
TCanvas* c44 = new TCanvas();
c44->SetTitle("NaI1 vs NaI2");
tree4->Draw("-A3:-A4", "-A4<0.03e-6 && -A3<0.03e-6","colz");                    // AREE
c44->Draw();

// %%
TCanvas* c442 = new TCanvas();
c442->SetTitle("Lyso vs NaI1");
tree4->Draw("-A2:-A3", Mask_Na22, "colz");

TCanvas* c45 = new TCanvas();
c45->SetTitle("Peak-to-peak ch 3 and 4");
tree4->Draw("PK3:PK4", Mask_Na22, "colz");                   // PICCHI
// Istogrammi con dati filtrati 
c44->Draw();

// %%
TCanvas* c46 = new TCanvas();
TH1D* h41 = new TH1D("h41","Peak @ 511 keV;NaI1 [Vs];Events",60,15e-9,27e-9);
h41->SetStats(0);
tree4->Draw("-A3>>h41", Mask_Na22, "colz");
gPad->SetLogy();

TF1* f41 = new TF1("f41","gaus+ [3]",15e-9,27e-9);
f41->SetParameter(0,100);
f41->SetParameter(1,23e-9);
f41->SetParameter(2,1e-9);
f41->SetParameter(3,1);
h41->Fit("f41","L", " ",15e-9,27e-9); //L:likelyhood 
c46->Draw();

double p41  = f41->GetParameter(1); //centro gaussiana
double ep41 = f41->GetParError(1); //suo errore
double s41  = f41->GetParameter(2); //sigma gaussiana
double e41  = f41->GetParError(2);  //suo errore
// Out:
//  FCN=21.6968 FROM MIGRAD    STATUS=FAILED        208 CALLS         209 TOTAL
//                      EDM=0.00806061    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.5 per cent
//   EXT PARAMETER                APPROXIMATE        STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  p0           1.05103e+02   2.45652e+00  -0.00000e+00  -9.99588e-04
//    2  p1           2.31177e-08   9.05442e-12   0.00000e+00  -4.73530e+09
//    3  p2           1.14658e-09   2.51880e-12  -0.00000e+00  -9.79740e+08
//    4  p3          -5.53299e+00   6.52603e-02  -0.00000e+00  -2.06789e-02
//                                ERR DEF= 0.5
// Warning in <Fit>: Abnormal termination of minimization.

// %%
TCanvas* c47 = new TCanvas();
TH1D* h42 = new TH1D("h42","Peak @ 511 keV;NaI2 [Vs];Events",50,17e-9,20e-9);
tree4->Draw("-A4>>h42", Mask_Na22, "colz");
h42->SetStats(0);
gPad->SetLogy();

TF1* f42 = new TF1("f42","gaus+ [3]",17e-9,20e-9);
f42->SetParameter(0,16);
f42->SetParameter(1,18.5e-9);
f42->SetParameter(2,1e-9);
f42->SetParameter(3,0);
h42->Fit("f42","L", " ",17e-9,20e-9); //L:likelyhood 
c47->Draw();

double p42  = f42->GetParameter(1); //centro gaussiana
double ep42 = f42->GetParError(1); //suo errore
double s42  = f42->GetParameter(2); //sigma gaussiana
double e42  = f42->GetParError(2);  //suo errore
// Out:
//  FCN=23.3005 FROM MIGRAD    STATUS=CONVERGED     190 CALLS         191 TOTAL
//                      EDM=8.70885e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  p0           4.73429e+01   6.48490e+00   3.60675e-03   2.00198e-04
//    2  p1           1.84678e-08   2.33386e-11   7.81907e-14   2.61145e+07
//    3  p2           8.80557e-10   1.28966e-10   6.25397e-14   3.50338e+07
//    4  p3          -5.70490e+00   7.18670e+00   2.06450e-03   8.26952e-04
//                                ERR DEF= 0.5

// %%
TCanvas* c48 = new TCanvas();
TH1D* h43 = new TH1D("h43","Peak @ 1275 keV;LYSO [Vs];Events",70,2e-9,9e-9);
//h43->SetStats(0);
tree4->Draw("-A2>>h43", Mask_Na22, "colz");
gPad->SetLogy();

TF1* f43 = new TF1("f43","[0]/(1 + (x/[4])**[5]) +gaus(1)",2e-9,9e-9);
f43->SetParameter(0,20);
f43->SetParameter(1,30);	// altezza
f43->SetParameter(2,6e-9); //centro gaussiana
f43->SetParameter(3,1e-9); //sigma gaussiana
f43->SetParameter(4,7e-9);
f43->SetParameter(5,5);
f43->SetParNames("const 1173 keV", "mean 1173 keV", "sigma 1275 keV", "a3", "a4", "a5");

h43->Fit("f43","L", " ", 2e-9, 9e-9); //L:likelyhood 
c48->SetGrid();
c48->Draw();

double p43   = f43->GetParameter(2); //centro gaussiana
double ep43  = f43->GetParError(2); //suo errore
double s43   = f43->GetParameter(3); //sigma gaussiana
double e43   = f43->GetParError(3);  //suo errore
// Out:
//  FCN=27.7378 FROM MIGRAD    STATUS=CONVERGED     301 CALLS         302 TOTAL
//                      EDM=4.42746e-09    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   2.7 per cent
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  const 1173 keV   1.60679e+01   7.23160e-01  -1.05310e-03  -5.39771e-05
//    2  mean 1173 keV   2.62617e+01   2.94309e+00  -9.73133e-04   2.22646e-06
//    3  sigma 1275 keV   5.91042e-09   4.10757e-11  -4.05036e-14  -8.49253e+05
//    4  a3           3.59588e-10   3.99997e-11   4.64714e-14  -2.03549e+06
//    5  a4           7.61323e-09   8.49802e-11   1.61733e-14   2.11437e+05
//    6  a5           2.43621e+01   3.91152e+00   2.59424e-03  -6.50189e-06
//                                ERR DEF= 0.5

// %%
cout << "Calibrazione con sorgente Na 22: 511 keV in NaI1 e NaI2" << endl;
cout << "NaI1" <<endl;
cout << "511 keV @ " << p41 << "+-" << ep41 << endl;
cout << "sig @ 511 keV " << s41 << "+-" << e41 << endl;
cout << "NaI2" <<endl;
cout << "511 keV @ " << p42 << "+-" << ep42 << endl;
cout << "sig @ 511 keV " << s42 << "+-" << e42 << endl;
cout << "LYSO" <<endl;
cout << "1275 keV @ " << p43 << "+-" << ep43 << endl;
cout << "sig @ 1275 keV " << s43 << "+-" << e43 << endl;

cout << "*********************************************************************************" << endl;  

calfile << "1275\t" << p43 << "\t" << ep43 << "\t 0 \t" <<s43<< "\t" << e43 << "\n";
// Out:
// Calibrazione con sorgente Na 22: 511 keV in NaI1 e NaI2
// NaI1
// 511 keV @ 2.31177e-08+-9.05442e-12
// sig @ 511 keV 1.14658e-09+-2.5188e-12
// NaI2
// 511 keV @ 1.84678e-08+-2.33386e-11
// sig @ 511 keV 8.80557e-10+-1.28966e-10
// LYSO
// 1275 keV @ 5.91042e-09+-4.10757e-11
// sig @ 1275 keV 3.59588e-10+-3.99997e-11
// *********************************************************************************

// %% [markdown]
// ### 2nd configuration

// %%
TString Fname7 = "DST/group2/Na2_2.dst";
TTree* tree5 = new TTree("tree5","data from ascii file");
tree5->ReadFile(Fname7.Data(),"evnum/I:A1/F:A2/F:A3/F:A4/F:T12/F:T32/F:T42/F:T34/F:PK1/F:PK2/F:PK3/F:PK4/F");

TString Mask_Na2_0 = "abs(T12-0.04e-6)<0.03e-6 && abs(T32- 6e-9)<0.02e-6 && T32!=0 && T12!=0";
TString Mask_Na2_1 = "&& abs(-A3-52e-9)<5e-9 && abs(-A4-20e-9)<8e-9";
TString Mask_Na2 = Mask_Na2_0 + Mask_Na2_1;

// %%
TCanvas* c51 = new TCanvas();
c51->SetTitle("Na_T32_T42");
tree5->Draw("T32:T42", Mask_Na2, "colz");
c51->Draw();

// %%
TCanvas* c512 = new TCanvas();
c512->SetTitle("Na_T34_T32");
tree5->Draw("T34:T32", Mask_Na2, "colz");  // because in 0 there is a noisy spot 
c512->Draw();

// %%
// ISTOGRAMMI AREE/PICCHI
// Pulisco i dati eliminando gli eventi di pile-up
TCanvas* c53 = new TCanvas();
c53->SetTitle("Areas/peaks");
tree5->Draw("-A3/PK3:-A4/PK4", Mask_Na2 , "colz");

// istogramma 2D delle aree NaI1 NaI2
TCanvas* c54 = new TCanvas();
c54->SetTitle("NaI1 and NaI2 Areas");
tree5->Draw("-A3:-A4", "-A4<50e-9 && -A3<0.06e-6","colz");                    // AREE
c54->Draw();

// %%
TCanvas* c542 = new TCanvas();
TH2D* h2dNa22= new TH2D("h2dNa22",";LYSO [Vs]; NaI2 [Vs]",70,0,3.5e-9,70,-5e-9,60e-9);
h2dNa22->SetStats(0);
tree5->Draw("-A3:-A2>>h2dNa22", "", "colz");
c542->Draw();

TCanvas* c543 = new TCanvas();
TH2D* h2dNa22_2= new TH2D("h2dNa22_2",";LYSO [Vs]; NaI1 [Vs]",70,0,3.5e-9,70,-5e-9,25e-9);
h2dNa22_2->SetStats(0);
tree5->Draw("-A4:-A2>>h2dNa22_2", "", "colz");
c543->Draw();

// %%
TCanvas* c55 = new TCanvas();
c55->SetTitle("Peak-to-peak NaI1 and NaI2");
tree5->Draw("PK3:PK4", Mask_Na2, "colz");                   // PICCHI
// Istogrammi con dati filtrati 
c55->Draw();

TCanvas* c56 = new TCanvas();
TH1D* h51 = new TH1D("h51","Peak @ 1275 keV;NaI1 [Vs];Events",100,0,7e-8);
h51->SetStats(0);
tree5->Draw("-A3>>h51", Mask_Na2, "colz");
gPad->SetLogy();

TF1* f51 = new TF1("f51","[0]+gaus(1)",0,7e-8);
f51->SetParameter(0,0);
f51->SetParameter(1,70);
f51->SetParameter(2,56.e-9); //centro gaussiana
f51->SetParameter(3,1e-9); //sigma gaussiana
h51->Fit("f51","L", " ", 47e-9, 58e-9); //L:likelyhood 
c56->Draw();

double p51  = f51->GetParameter(2); //centro gaussiana
double ep51 = f51->GetParError(2); //suo errore
double s51  = f51->GetParameter(3); //sigma gaussiana
double e51  = f51->GetParError(3);  //suo errore
// Out:
//  FCN=21.0217 FROM MIGRAD    STATUS=CONVERGED     177 CALLS         178 TOTAL
//                      EDM=2.60628e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   3.6 per cent
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  p0           1.95619e+00   9.34027e-01   2.66079e-03  -7.33274e-04
//    2  p1           9.56405e+01   5.74868e+00   8.27050e-03  -1.31884e-04
//    3  p2           5.19922e-08   7.26439e-11   3.07516e-13   4.12064e+06
//    4  p3           1.31017e-09   7.97081e-11  -1.51547e-13  -7.02018e+06
//                                ERR DEF= 0.5

// %%
cout << "NaI1" <<endl;
cout << "1275 keV@ " << p51 << "+-" << ep51 << endl;
cout << "sig @ 1275 keV " << s51 << "+-" << e51 << endl;
// Out:
// NaI1
// 1275 keV@ 5.19922e-08+-7.26439e-11
// sig @ 1275 keV 1.31017e-09+-7.97081e-11

// %%
TCanvas* c57 = new TCanvas();
TH1D* h52 = new TH1D("h52","Peak @ 511 keV;NaI2 [Vs];Events",200,0,3e-8);
h52->SetStats(0);
tree5->Draw("-A4>>h52", Mask_Na2, "colz");
gPad->SetLogy();

TF1* f52 = new TF1("f52","[0]+gaus(1)",0,7e-8);
f52->SetParameter(0,0);
f52->SetParameter(1,70);	// altezza
f52->SetParameter(2,17.e-9); //centro gaussiana
f52->SetParameter(3,1e-9); //sigma gaussiana
h52->Fit("f52","L", " ", 14e-9, 21e-9); //L:likelyhood 
c57->Draw();

double p52  = f52->GetParameter(2); //centro gaussiana
double ep52 = f52->GetParError(2); //suo errore
double s52  = f52->GetParameter(3); //sigma gaussiana
double e52  = f52->GetParError(3);  //suo errore
// Out:
//  FCN=38.1032 FROM MIGRAD    STATUS=CONVERGED     369 CALLS         370 TOTAL
//                      EDM=6.0434e-08    STRATEGY= 1  ERROR MATRIX UNCERTAINTY  11.1 per cent
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  p0           2.62718e+00   6.30259e-01  -1.28406e-03   5.43084e-04
//    2  p1           1.72042e+01   1.40439e+00   9.58177e-03   6.13657e-05
//    3  p2           1.84829e-08   9.19707e-11   2.90748e-13   1.25665e+06
//    4  p3           1.12184e-09   1.17554e-10  -2.42266e-13   1.02310e+06
//                                ERR DEF= 0.5

// %%
TCanvas* c58 = new TCanvas();
TH1D* h53 = new TH1D("h53","Peak @ 511 keV;LYSO [Vs];Events",40,0.5e-9,3.5e-9);
//h53->SetStats(0);
tree5->Draw("-A2>>h53", Mask_Na2, "colz");
gPad->SetLogy();

TF1* f53 = new TF1("f53","gaus+ [3] /(1 + (x/[4])**[5])",0.5e-9,3.5e-9);
f53->SetParameter(0,30);
f53->SetParameter(1,2.2e-9);
f53->SetParameter(2,0.25e-9);
f53->SetParameter(3,8);
f53->SetParameter(4,3e-9);
f53->SetParameter(5,2);
f53->SetParNames("const 511 keV", "mean 511 keV", "sigma 511 keV", "a3", "a4", "a5");
h53->Fit("f53","L", " ", 0.5e-9,3.5e-9); //L:likelyhood 
c58->SetGrid();
c58->Draw();

double p53  = f53->GetParameter(1); //centro gaussiana
double ep53 = f53->GetParError(1); //suo errore
double s53  = f53->GetParameter(2); //sigma gaussiana
double e53  = f53->GetParError(2);  //suo errore
// Out:
//  FCN=22.5241 FROM MIGRAD    STATUS=CONVERGED     402 CALLS         403 TOTAL
//                      EDM=1.15023e-07    STRATEGY= 1  ERROR MATRIX UNCERTAINTY   3.2 per cent
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  const 511 keV   3.47676e+01   3.06634e+00   3.46448e-03  -3.96770e-05
//    2  mean 511 keV   2.17096e-09   1.93305e-11  -1.04682e-14   9.52774e+06
//    3  sigma 511 keV   2.32931e-10   2.20722e-11   1.04866e-14  -5.72902e+05
//    4  a3           5.35657e+00   6.55253e-01  -8.46748e-05  -2.98274e-04
//    5  a4           3.17773e-09   9.04409e-11  -1.34960e-13  -4.27400e+06
//    6  a5           1.95439e+01   7.73760e+00   1.09486e-02   2.58152e-06
//                                ERR DEF= 0.5

// %%
cout << "Calibrazione con sorgente Na 22: 511 keV in NaI2 e LYSO" << endl;
cout << "NaI1" <<endl;
cout << "1275 keV @ " << p51 << "+-" << ep51 << endl;
cout << "sig @ 1275 keV " << s51 << "+-" << e51 << endl;
cout << "NaI2" <<endl;
cout << "511 keV @ " << p52 << "+-" << ep52 << endl;
cout << "sig @ 511 keV " << s52 << "+-" << e52 << endl;
cout << "LYSO" <<endl;
cout << "511 keV @ " << p53 << "+-" << ep53 << endl;
cout << "sig @ 511 keV " << s53 << "+-" << e53 << endl;

cout<<"*********************************************************************************" << endl; 	   

calfile << "511\t" << p53 << "\t" << ep53 << "\t 0 \t" <<s53<< "\t" << e53 << "\n";
// Out:
// Calibrazione con sorgente Na 22: 511 keV in NaI2 e LYSO
// NaI1
// 1275 keV @ 5.19922e-08+-7.26439e-11
// sig @ 1275 keV 1.31017e-09+-7.97081e-11
// NaI2
// 511 keV @ 1.84829e-08+-9.19707e-11
// sig @ 511 keV 1.12184e-09+-1.17554e-10
// LYSO
// 511 keV @ 2.17096e-09+-1.93305e-11
// sig @ 511 keV 2.32931e-10+-2.20722e-11
// *********************************************************************************

// %% [markdown]
// # Calibration curve

// %%
TTree* tree = new TTree("tree", "data from asci file");
tree->ReadFile("docs/group2/Calibration_data_for_fit.txt","ene/F:cal/F:ecal/F:syscal/F:sigma/F:esigma/F");

tree->Draw("cal:ene:ecal+syscal");
TGraphErrors* gra = new TGraphErrors(tree->GetSelectedRows(),tree->GetV2(),tree->GetV1(),tree->GetV4(),tree->GetV3());
TCanvas* c91 = new TCanvas();
gra->Draw("ap");
gra->SetLineWidth(2);

TF1* flin = new TF1("flin","pol1",0,1500);
flin->SetParameter(1,10e-11);
gra->Fit("flin");
gra->GetXaxis()->SetTitle("Energy [keV]");
gra->GetXaxis()->SetRange(-20,1500);
gra->GetYaxis()->SetTitle("LYSO signal [Vs]");
gra->SetTitle("Calibration Curve");
c91->SetGrid();
c91->Draw();

double pl1=flin->GetParameter(1);
double pl0=flin->GetParameter(0);
// Out:
// <div id="root_plot_1655287194545"
//      style="width: 696px; height: 472px">
// </div>
// <script>
//
// function display_root_plot_1655287194545(Core) {
// ...

// %%
TCanvas* c92 = new TCanvas();	
tree->Draw(Form("sigma*%e:ene:(esigma)*%e:ene*0.001",1/pl1,1/pl1),"","goff"); // sigma in keV
TGraphErrors* gra2 = new TGraphErrors(tree->GetSelectedRows(),tree->GetV2(),tree->GetV1(),tree->GetV4(),tree->GetV3());

gra2->Draw("ap");
gra2->SetLineWidth(2);

TF1* fsig = new TF1("fsig","sqrt([1]*[1]*x+[0]*[0])",0,1500);
fsig->SetParameter(0,10);
fsig->SetParameter(1,5);
gra2->Fit("fsig");
gra2->GetXaxis()->SetTitle("Energy [keV]");
gra2->GetXaxis()->SetRange(-20,1500);
gra2->GetYaxis()->SetTitle("#sigma [keV]");
gra2->SetTitle("Residues");
c92->SetGrid();
//fsig->SetStats(0);
c92->Draw();
// Out:
// <div id="root_plot_1655288928843"
//      style="width: 696px; height: 472px">
// </div>
// <script>
//
// function display_root_plot_1655288928843(Core) {
// ...

// %% [markdown]
// # Source Discovery: Cs137

// %%
//import data
TTree* treeCS = new TTree("treeCS","data from ascii file");
TList* treeList = new TList;
//data for CS
treeCS->ReadFile("DST/group2/CS2.dst","evnum/I:A1/F:A2/F:A3/F:A4/F:T12/F:T32/F:T42/F:T34/F:PK1/F:PK2/F:PK3/F:PK4/F");

//data for LYSO
TTree* treeLYSO = new TTree("treeLYSO","data from ascii file");
treeLYSO->ReadFile("DST/group2/LYSO6.dst","evnum/I:A1/F:A2/F:A3/F:A4/F:T12/F:T32/F:T42/F:T34/F:PK1/F:PK2/F:PK3/F:PK4/F");
treeLYSO->ReadFile("DST/group2/LYSO5.dst","evnum/I:A1/F:A2/F:A3/F:A4/F:T12/F:T32/F:T42/F:T34/F:PK1/F:PK2/F:PK3/F:PK4/F");

//Selection rules string
TString rules = "-A3<-1e-9 && -A4<-0.4e-9 && abs(-A2/PK2-0.09e-6)<0.03e-6";

// %%
//plot for filtering the data
//This part is needed to check if there is already a C1 and if there is delete it
TCanvas *C1 = (TCanvas*) gROOT->FindObject("C1");
if (C1) delete C1;
C1 = new TCanvas("C1","canvas",2096,640);
//divide the canvas in 2
C1->Divide(2,1);

//just drawing the tree should be faster than using histograms as it auto selects the range
//select which canvas to use
C1->cd(1);
//TH2D *h2Darea = new TH2D("h2Darea",";NaI1[V s];NaI2 [V s]",200,0e-9,90e-9,200,0e-9,90e-9);
treeLYSO->Draw("-A2/PK2:A1/PK1", rules.Data(), "colz");

C1->cd(2);
//TH2D *h2Ddelay = new TH2D("h2Ddelay",";A3/PK3[V s];T32 [s]",200,0e-9,30e-9,200,0e-9,30e-9);
treeLYSO->Draw("-A4:-A3", rules.Data(), "colz");
C1->Draw();

// %%
TString rules_extra = "";

TCanvas *C2 = (TCanvas*) gROOT->FindObject("C2");
if (C2) delete C2;
C2 = new TCanvas("C2","canvas",2096,640);
C2->Divide(2,1);

//create new histograms

TH1D *hLYSO = (TH1D*) gROOT->FindObject("hLYSO");
if (hLYSO) delete hLYSO;
hLYSO = new TH1D("hLYSO","LYSO;EnergyLYSO [Vs];Events",140,0,9e-9);
hLYSO->SetStats(0);

TH1D *hCS = (TH1D*) gROOT->FindObject("hCS");
if (hCS) delete hCS;
hCS = new TH1D("hCS","LYSO+Cs;EnergyLYSO [Vs];Events",140,0,9e-9);
hCS->SetStats(0);

treeCS->Draw("ELYSO>>hCS", rules.Append(rules_extra.Data()).Data(), "same");
//gPad->SetLogy();
C2->Draw();
//integrate the tails
hCS->SetLineColor(4);
hCS->SetLineWidth(2);
hLYSO->SetLineColor(2);
hLYSO->SetLineWidth(2);
//create new variables in the two trees
C2->cd(1);
gPad->SetLogy();
gPad->SetGrid();
treeLYSO->Draw("-A2>>hLYSO", rules.Data(), "");
C2->cd(2);
gPad->SetLogy();
gPad->SetGrid();
treeCS->Draw("-A2>>hCS", rules.Data(), "");
//gPad->SetLogy();
C2->Draw();
// Out:
// Error in <TTreeFormula::Compile>:  Bad numerical expression : "ELYSO"
// Info in <TSelectorDraw::AbortProcess>: Variable compilation failed: {ELYSO,-A3<-1e-9 && -A4<-0.4e-9 && abs(-A2/PK2-0.09e-6)<0.03e-6}

// %%
//fit the data
//this rules can be useful to select sub ranges
TString rules_extra = "";//&& -A2>0e-9 && -A2<8e-9 ";
TCanvas *C2 = (TCanvas*) gROOT->FindObject("C2");
if (C2) delete C2;
C2 = new TCanvas("C2","canvas",1048,640);
//create new histograms
TH1D* hLYSO = new TH1D("hLYSO","LYSO and LYSO+Cs;EnergyLYSO [keV];Events",80,0,2e3);
hLYSO->SetStats(0);
TH1D* hCS = new TH1D("hCS","LYSO and LYSO+Cs;EnergyLYSO [keV];Events",80,0,2e3);
hCS->SetStats(0);
hCS->SetLineColor(2);
hCS->SetLineWidth(2);
hCS->SetMarkerStyle(2);
gPad->SetGridy();
gPad->SetLogy();
hLYSO->SetMarkerStyle(8);
hLYSO->SetMarkerColor(1);
hLYSO->SetLineColor(1);
hLYSO->SetMarkerSize(0.6);
//calibration
double Pl0 = 2.163338e-10;
double Pl1 = 2.085267e+11;
//create new variables in the two trees
treeLYSO->SetAlias("ELYSO",Form("((-A2+%g)*%g)",Pl0,Pl1));
treeCS->SetAlias("ELYSO",Form("((-A2+%g)*%g)",Pl0,Pl1));
treeLYSO->Draw("ELYSO>>hLYSO", rules.Append(rules_extra.Data()).Data(), "");
//C2->Draw();

treeCS->Draw("ELYSO>>hCS", rules.Append(rules_extra.Data()).Data(), "same");
//gPad->SetLogy();

auto legend = new TLegend(0.1,0.7,0.48,0.9);
//legend->SetHeader("Legend","C"); // option "C" allows to center the header
legend->AddEntry(hLYSO,"LYSO bkg","l");
legend->AddEntry(hCS,"137Cs Run","l");
legend->Draw();
C2->Draw();
// Out:
// Warning in <TROOT::Append>: Replacing existing TH1: hLYSO (Potential memory leak).
// Warning in <TROOT::Append>: Replacing existing TH1: hCS (Potential memory leak).

// %%
//integrate the tails

double E_int = 0.9e3;
double intCS = hCS->Integral(hCS->FindBin(E_int),hCS->GetNbinsX());
double intLYSO = hLYSO->Integral(hLYSO->FindBin(E_int),hLYSO->GetNbinsX());
cout << intCS/intLYSO << endl;
hLYSO->Scale(intCS/intLYSO);

double E_0 = 400; // estremi per il fit
double E_1 = 900;

TCanvas *C3 = (TCanvas*) gROOT->FindObject("C3");
if (C3) delete C3;
C3 = new TCanvas("C3","canvas",1048,640);
TH1D* hdiff = (TH1D*)hCS->Clone("hdiff");
hdiff->Add(hLYSO,-1);
hdiff->Draw("Same");
hdiff->SetMarkerStyle(8);
hdiff->SetMarkerColor(1);
hdiff->SetLineColor(1);
hdiff->SetMarkerSize(0.6);
gPad->SetGrid();
//hdiff->SaveAs("Hdiff2.root");
hdiff->SetTitle("Cs");
hdiff->GetYaxis()->SetTitle("Residues");
TF1* f1 = new TF1("f1","[0]*exp(-(x)/[4])+gaus(1) + [5]",E_0,E_1);
f1->SetParameter(0,250);
f1->SetParameter(1,200);
f1->SetParameter(2,661);//centro gaussiana
f1->SetParameter(3,30); //sigma gaussiana
f1->SetParameter(4,100);
f1->SetParameter(5,-1);
f1->SetParNames("a3", "const", "mean", "sigma", "a4", "a5");
hdiff->Fit("f1","L", "", E_0, E_1); //L:likelyhood
//C3->SaveAs("IMAGE/CS.root");
//C3->SaveAs("IMAGE/CS.png");
gStyle->SetOptStat(0);
gStyle->SetOptFit(1);
C3->Draw();
// Out:
// 1
//  FCN=70.8625 FROM MIGRAD    STATUS=CONVERGED    1654 CALLS        1655 TOTAL
//                      EDM=2.94083e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
//   EXT PARAMETER                                   STEP         FIRST
//   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
//    1  a3           3.42488e+02   3.13559e+01   3.90486e-02  -2.94999e-06
//    2  const        1.91088e+02   7.13496e+00   3.34511e-02   7.48510e-05
//    3  mean         6.46504e+02   2.48360e+00   1.08949e-02   1.29168e-04
//    4  sigma        6.46902e+01   2.35568e+00   5.44647e-03   1.31412e-04
//    5  a4           2.84816e+02   1.52312e+01   1.17919e-02   2.76426e-06
//    6  a5          -2.02124e+01   2.06961e+00   2.27338e-03   5.03217e-05
//                                ERR DEF= 0.5

// %% [markdown]
// The peak we see corresponds to the peak at 661.7 keV. From the measurements we have  646.505+-2, which

// %% [markdown]
// # Simulation with Geant4

// %%
TString PREFIX = "SimulazioneGeant4/";
TString fname = PREFIX + "NaI1NaI2LYSO_Co60.root";

// Read data
TFile* fCo = TFile::Open(fname.Data());
fname.ReplaceAll("NaI1NaI2LYSO_Co60.root","NaI1NaI2LYSO_Cs137.root");
TFile* fCs = TFile::Open(fname.Data());
fname.ReplaceAll("NaI1NaI2LYSO_Cs137.root","NaI1NaI2LYSO_Na22.root");
TFile* fNa = TFile::Open(fname.Data());
fname.ReplaceAll("NaI1NaI2LYSO_Na22.root","NaI1NaI2_noLYSO_Co60.root");
TFile* fCoNo = TFile::Open(fname.Data());
fname.ReplaceAll("NaI1NaI2_noLYSO_Co60.root","NaI1NaI2_noLYSO_Na22.root");
TFile* fNaNo = TFile::Open(fname.Data());

TTree* treeCo  = (TTree*)fCo->Get("T");
//treeCo->Print();
TTree* treeCs = (TTree*)fCs->Get("T");
TTree* treeNa = (TTree*)fNa->Get("T");
TTree* treeCoNo = (TTree*)fCoNo->Get("T");
TTree* treeNaNo = (TTree*)fNaNo->Get("T");

// %% [markdown]
// ### In the LYSO

// %%
// Co 60

TCanvas *cCo = (TCanvas*) gROOT->FindObject("cCo");
if (cCo) delete cCo;
cCo = new TCanvas("cCo","canvas",1048,640);
treeCo->Draw("Edep_LYSO");
gPad->SetLogy();
TPaveText *t = new TPaveText(0.0, 0.9, 0.5, 1.0, "brNDC"); // left-up 
t->AddText("Energy deposited in LYSO from a Co 60 source [MeV]");
t->Draw();
gStyle->SetOptTitle(0);
gPad->SetGrid();
cCo->Draw();

// %%
#include <iostream>
#include <fstream>  
double Edep_LYSO;
treeCo->SetBranchAddress("Edep_LYSO", &Edep_LYSO);

std::ofstream outfile ("test.csv");

for (int i=0; i<n; i++) { // riempie con i dati
    treeCo->GetEntry(i);
    outfile << Edep_LYSO << std::endl;
}



outfile.close();

// %% [markdown]
// double Edep_LYSO;
// treeCo->SetBranchAddress("Edep_LYSO", &Edep_LYSO);
//
// double E; //smeared energies
// double smear=0;
// TTree *treeCoSmeared = (TTree*) gROOT->FindObject("treeCoSmeared");
// if (treeCoSmeared) delete treeCoSmeared;
// treeCoSmeared = new TTree("treeCoSmeared","T");
// TBranch *branch = treeCoSmeared->Branch("smear",&smear,"smear/F");
//
//
// TCanvas *c1 = (TCanvas*) gROOT->FindObject("c1");
// if (c1) delete c1;
// c1 = new TCanvas();
// TH1F *h = new TH1F("h","htitle",100,0,3); // crea “h”
//
//
// int n = treeCo->GetEntries();
// TRandom rdn;
// rdn.SetSeed(0);
//
//
// double sigma = 1e-9;
//
// for (int i=0; i<n; i++) { // riempie con i dati
//     treeCo->GetEntry(i);
//     //smear = rdn.Gaus(0, sigma);
//     //cout<<smear<<endl;
//     E=Edep_LYSO+smear;
//     treeCoSmeared->Fill();
//     h->Fill(E);
// }
//
// treeCoSmeared->Draw("E>>h");
// gPad->SetLogy();
// h->GetXaxis()->SetTitle("Energy [keV]");
// h->GetYaxis()->SetTitle("Counts");
//
// c1->Draw();

// %% [markdown]
// // Smearing
// for (int i = 0; i < Tree->GetEntries(); i++) {
//     Tree->Fill

// %%
// Cs 137
TCanvas *cCs = (TCanvas*) gROOT->FindObject("cCs");
if (cCs) delete cCs;
cCs = new TCanvas("cCs","canvas",1048,640);
treeCs->Draw("Edep_LYSO");
gPad->SetLogy();
TPaveText *t = new TPaveText(0.0, 0.9, 0.5, 1.0, "brNDC"); // left-up 
t->AddText("Energy deposited in LYSO from a Cs 137 source [MeV]");
t->Draw();
gStyle->SetOptTitle(0);
gPad->SetGrid();
cCs->Draw();

// %%
// Na 22
TCanvas *cNa = (TCanvas*) gROOT->FindObject("cNa");
if (cNa) delete cNa;
cNa = new TCanvas("cNa","canvas",1048,640);
treeNa->Draw("Edep_LYSO");
gPad->SetGrid();
gPad->SetLogy();
TPaveText *t = new TPaveText(0.0, 0.9, 0.5, 1.0, "brNDC"); // left-up 
t->AddText("Energy deposited in LYSO from a Na 22 source [MeV]");
t->Draw();
gStyle->SetOptTitle(0);

cNa->Draw();

// %% [markdown]
// ### Without LYSO

// %%
// Co 60
TCanvas *cCoNo = (TCanvas*) gROOT->FindObject("cCoNo");
if (cCoNo) delete cCoNo;
cCoNo = new TCanvas("cCoNo","canvas",1048,640);
treeCoNo->Draw("Edep_NaI1");
gPad->SetLogy();
TPaveText *t = new TPaveText(0.0, 0.9, 0.5, 1.0, "brNDC"); // left-up 
t->AddText("Energy deposited in NaI1 from a Co 60 source without LYSO [MeV]");
t->Draw();
gStyle->SetOptTitle(0);
gPad->SetGrid();
cCoNo->Draw();

// %%
// Na 22
TCanvas *cNaNo = (TCanvas*) gROOT->FindObject("cNaNo");
if (cNaNo) delete cNaNo;
cNaNo = new TCanvas("cNaNo","canvas",1048,640);
treeNaNo->Draw("Edep_NaI1");
gPad->SetLogy();
TPaveText *t = new TPaveText(0.0, 0.9, 0.5, 1.0, "brNDC"); // left-up 
t->AddText("Energy deposited in NaI1 from a Na 22 source without LYSO [MeV]");
t->Draw();
gStyle->SetOptTitle(0);
gPad->SetGrid();
cNaNo->Draw();

// %% [markdown]
// ### LYSO intrinsic radiation

// %%
// LYSO

TString fname = PREFIX + "onlyLYSO.root";
TFile* fLYSO2 = TFile::Open(fname.Data());

TTree* treeLYSO2 = (TTree*)fLYSO2->Get("T");
TCanvas *cLYSO2 = (TCanvas*) gROOT->FindObject("cLYSO2");
if (cLYSO2) delete cLYSO2;
cLYSO2 = new TCanvas("cLYSO2","canvas",1048,640);
treeLYSO2->Draw("Edep_NaI1");
gPad->SetLogy();
TPaveText *t = new TPaveText(0.0, 0.9, 0.5, 1.0, "brNDC"); // left-up 
t->AddText("Energy deposited in NaI1 from LYSO alone [MeV]");
t->Draw();
gStyle->SetOptTitle(0);
gPad->SetGrid();
cLYSO2->Draw();
